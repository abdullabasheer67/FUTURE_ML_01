# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("data/raw/retail_sales.xlsx.csv")
df.head()
# Out:
#          data  venda  estoque  preco
# 0  2014-01-01      0     4972   1.29
# 1  2014-01-02     70     4902   1.29
# 2  2014-01-03     59     4843   1.29
# 3  2014-01-04     93     4750   1.29
# 4  2014-01-05     96     4654   1.29

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 937 entries, 0 to 936
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     937 non-null    object
#  1   venda    937 non-null    int64
#  2   estoque  937 non-null    int64
#  3   preco    937 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 29.4+ KB

# %%
df.describe()
# Out:
#             venda      estoque       preco
# count  937.000000   937.000000  937.000000
# mean    90.533618  1608.258271    1.592572
# std     80.682089  1356.691877    0.529502
# min      0.000000     0.000000    0.000000
# 25%     33.000000   794.000000    1.290000
# 50%     76.000000  1348.000000    1.390000
# 75%    127.000000  1964.000000    1.890000
# max    542.000000  7228.000000    2.980000

# %%
plt.figure(figsize=(12,5))
plt.plot(df['data'], df['venda'], color='blue')
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Sales')
plt.title('Salimport seaborn as sns
sns.histplot(df['venda'], bins=20)
es Over Time')
plt.show()

# %%
sns.histplot(df['venda'], bins=20)
# Out:
# <AxesSubplot:xlabel='venda', ylabel='Count'>

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['venda'], bins=20, kde=True, color='green')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Sales Distribution')
plt.show()

# %%
df.isnull().sum()
# Out:
# data       0
# venda      0
# estoque    0
# preco      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns = ['date','sales','stock','price']
